# %%
import h5py

def print_objs (name):
   print (name)

fd = h5py.File('models.hdf5', 'r')
fd.visit(print_objs)
print(fd['models_03/nu'][:])
# Out:
# models_00
# models_00/mass
# models_00/nu
# models_00/r
# models_01
# models_01/mass
# models_01/nu
# models_01/r
# models_02
# models_02/mass
# models_02/nu
# models_02/r
# models_03
# models_03/mass
# models_03/nu
# models_03/r
# models_04
# models_04/mass
# models_04/nu
# models_04/r
# models_05
# models_05/mass
# models_05/nu
# models_05/r
# models_06
# models_06/mass
# models_06/nu
# models_06/r
# models_07
# models_07/mass
# models_07/nu
# models_07/r
# models_08
# models_08/mass
# models_08/nu
# models_08/r
# models_09
# models_09/mass
# models_09/nu
# models_09/r
# models_10
# models_10/mass
# models_10/nu
# models_10/r
# models_11
# models_11/mass
# models_11/nu
# models_11/r
# models_12
# models_12/mass
# models_12/nu
# models_12/r
# models_13
# models_13/mass
# models_13/nu
# models_13/r
# models_14
# models_14/mass
# models_14/nu
# models_14/r
# models_15
# models_15/mass
# models_15/nu
# models_15/r
# models_16
# models_16/mass
# models_16/nu
# models_16/r
# models_17
# ...
